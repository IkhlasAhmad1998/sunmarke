# %%
# import scraping libraries
import requests
from bs4 import BeautifulSoup
import time

# %%
# init variables and containers
BASE_URL = "https://www.sunmarke.com"
visited = set()
documents = {}
menu_dict = {}

# %%
# parse homepage menu and collect links
homepage = requests.get(BASE_URL).text
soup = BeautifulSoup(homepage, "html.parser")


top_lis = soup.select("#menu-website-menu-1.sf-menu > li")

for li in top_lis:
    top_label = li.find("a").get_text(strip=True)
    
    # Get all links under this <li> recursively
    # urls = [urljoin(BASE_URL, a["href"]) for a in li.find_all("a", href=True)]
    urls = [a['href'] for a in li.find_all("a", href=True) if "class" not in a.attrs]

    # Special case: Contact Us (or any top-level that is a real page)
    if top_label.lower() == "contact us":
        urls.insert(0, li.find("a")["href"])  # add its own link at the beginning
    
    # Store under top-level label
    menu_dict[top_label] = urls

# %%
# debug print menu summary
print("total items: ", len(menu_dict))
for item in menu_dict.items():
    print(item[0], " : ", len(item[1]))
# Out:
# total items:  8
# About  :  11
# Learning  :  29
# Signature Programmes  :  9
# Admissions  :  7
# For Parents  :  10
# Activities  :  3
# News & Events  :  4
# Contact Us  :  2

# %%
# list menu items for inspection
for keys, values in menu_dict.items():
    print(keys, values)
# Out:
# About ['https://www.sunmarke.com/about/principals-message/', 'https://www.sunmarke.com/about/mission-vision-values/', 'https://www.sunmarke.com/about/a-positive-education-school/', 'https://www.sunmarke.com/about/leadership/', 'https://www.sunmarke.com/about/academic-results/', 'https://www.sunmarke.com/about/inspection-reports/', 'https://www.sunmarke.com/about/our-achievements/', 'https://www.sunmarke.com/about/sunmarke-alumni/', 'https://www.sunmarke.com/about/wellbeing/', 'https://www.sunmarke.com/about/the-achievement-centre-inclusion-department/', 'https://www.sunmarke.com/about/our-campus/']
# Learning ['https://www.sunmarke.com/learning/nursery/our-approach/', 'https://www.sunmarke.com/learning/nursery/enriched-learning/', 'https://www.sunmarke.com/learning/eyfs/our-approach-eyfs/', 'https://www.sunmarke.com/learning/eyfs/early-years-curriculum/', 'https://www.sunmarke.com/learning/eyfs/eyfs-enriched-learning/', 'https://www.sunmarke.com/learning/primary/our-approach-primary/', 'https://www.sunmarke.com/learning/primary/our-curriculum-primary/', 'https://www.sunmarke.com/learning/primary/sports-pe-primary/', 'https://www.sunmarke.com/learning/primary/creative-performing-arts-primary/', 'https://www.sunmarke.com/learning/primary/enriched-learning-primary/', 'https://www.sunmarke.com/learning/coding/', 'https://www.sunmarke.com/learning/primary/student-council-and-ambassadors/', 'https://www.sunmarke.com/learning/secondary/our-approach-secondary/', 'https://www.sunmarke.com/learning/secondary/our-curriculum-secondary/', 'https://www.sunmarke.com/learning/secondary/sports-pe-secondary/', 'https://www.sunmarke.com/learning/secondary/secondary-creative-performing-arts/', 'https://www.sunmarke.com/learning/secondary/enriched-learning-secodary/', 'https://www.sunmarke.com/learning/coding/', 'https://www.sunmarke.com/learning/secondary/sunmarke-mini-mba/', 'https://www.sunmarke.com/learning/secondary/student-council-and-ambassadors-secondary/', 'https://www.sunmarke.com/learning/sixth-form/our-approach-sixth-form/', 'https://www.sunmarke.com/learning/sixth-form/a-levels/', 'https://www.sunmarke.com/learning/sixth-form/btecs/', 'https://www.sunmarke.com/learning/sixth-form/ib-diploma-programme-ibdp/', 'https://www.sunmarke.com/learning/sixth-form/student-enrichment/', 'https://www.sunmarke.com/learning/coding/', 'https://www.sunmarke.com/learning/sixth-form/civitas/', 'https://www.sunmarke.com/learning/sixth-form/careers-counsellor/', 'https://www.sunmarke.com/learning/sixth-form/student-leadership/']
# Signature Programmes ['https://www.sunmarke.com/signature-programmes/steam-design-thinking/', 'https://www.sunmarke.com/signature-programmes/environment-and-sustainability/', 'https://www.sunmarke.com/signature-programmes/university-career-readiness-programme/', 'https://www.sunmarke.com/signature-programmes/fortes-pro-sports-academy/', 'https://www.sunmarke.com/signature-programmes/positive-education/', 'https://www.sunmarke.com/signature-programmes/global-language-academy/', 'https://www.sunmarke.com/signature-programmes/financial-literacy-programme/', 'https://www.sunmarke.com/signature-programmes/enterprise-mini-mba-programme/', 'https://www.sunmarke.com/signature-programmes/communications-media-the-performing-arts-programme/']
# Admissions ['https://applynow.sunmarke.com/', 'https://enquiry.sunmarke.com/enrolment-campaign?s=WEB', 'https://www.sunmarke.com/admissions/tuition-fees/', 'https://www.sunmarke.com/admissions/scholarships/', 'https://www.sunmarke.com/admissions/re-enrol-online/', 'https://www.sunmarke.com/admissions/school-forms/', 'https://www.sunmarke.com/admissions/faqs/']
# For Parents ['https://www.sunmarke.com/for-parents/school-uniform/', 'https://www.sunmarke.com/for-parents/school-timings/', 'https://www.sunmarke.com/for-parents/academic-calendar/', 'https://www.sunmarke.com/school-calendar-events', 'https://www.sunmarke.com/for-parents/policies/', 'https://www.sunmarke.com/for-parents/transport-services/', 'https://www.sunmarke.com/for-parents/dining-catering/', 'https://sports.sunmarke.com/', 'https://www.sunmarke.com/for-parents/parent-engagement/', 'https://www.sunmarke.com/for-parents/governance-committee/']
# Activities ['https://www.sunmarke.com/activities/sunmarke-free-ecas/', 'https://www.sunmarke.com/activities/sunmarke-paid-ecas/', 'https://www.sunmarke.com/activities/third-party-paid-ecas/']
# News & Events ['https://www.sunmarke.com/news-events/weekly-buzz/', 'https://www.sunmarke.com/news-events/blog/', 'https://www.sunmarke.com/news-events/press/', 'https://www.sunmarke.com/news-events/podcasts/']
# Contact Us ['https://www.sunmarke.com/contact-us/', 'https://www.sunmarke.com/contact-us/work-with-us/']

# %%
# prepare data store and headers
data = {key.lower(): [] for key in menu_dict}
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

# %%
# iterate URLs, extract main content with Trafilatura/BeautifulSoup
for label, urls in menu_dict.items():
    for url in urls:
        try:
            print(f"Scraping {url}")
            html = requests.get(url, headers=headers)
            
            # Extract clean text using Trafilatura
            soup = BeautifulSoup(html.text, "html.parser")

            # pick the div
            main_div = soup.find("div", class_="gdlr-core-page-builder-body clearfix")
            if main_div:
                text = main_div.get_text(separator="\n", strip=True)

            else:
                tags = soup.find_all(["p", "h1", "h2"])
                text = " ".join([t.get_text(strip=True) for t in tags if t.get_text(strip=True)])
            
            if text and len(text.strip()) > 300:  # skip tiny/empty pages
                document = {
                    "url": url,
                    "content": text.strip()
                }
                print(f"  ✅ Extracted {len(text.split())} words")
                data[label.lower()].append(document)
                time.sleep(10)
            else:
                print(f"  ⚠️ No meaningful text found")
        except Exception as e:
            print(f"  ❌ Error scraping {url}: {e}")
# Out:
# Scraping https://www.sunmarke.com/about/principals-message/
#   ✅ Extracted 457 words
# Scraping https://www.sunmarke.com/about/mission-vision-values/
#   ✅ Extracted 494 words
# Scraping https://www.sunmarke.com/about/a-positive-education-school/
#   ✅ Extracted 625 words
# Scraping https://www.sunmarke.com/about/leadership/
#   ✅ Extracted 447 words
# Scraping https://www.sunmarke.com/about/academic-results/
#   ✅ Extracted 275 words
# Scraping https://www.sunmarke.com/about/inspection-reports/
#   ✅ Extracted 295 words
# Scraping https://www.sunmarke.com/about/our-achievements/
#   ✅ Extracted 511 words
# Scraping https://www.sunmarke.com/about/sunmarke-alumni/
#   ✅ Extracted 307 words
# Scraping https://www.sunmarke.com/about/wellbeing/
#   ✅ Extracted 375 words
# Scraping https://www.sunmarke.com/about/the-achievement-centre-inclusion-department/
#   ✅ Extracted 480 words
# Scraping https://www.sunmarke.com/about/our-campus/
#   ✅ Extracted 79 words
# Scraping https://www.sunmarke.com/learning/nursery/our-approach/
#   ✅ Extracted 1134 words
# Scraping https://www.sunmarke.com/learning/nursery/enriched-learning/
#   ✅ Extracted 225 words
# Scraping https://www.sunmarke.com/learning/eyfs/our-approach-eyfs/
#   ✅ Extracted 352 words
# Scraping https://www.sunmarke.com/learning/eyfs/early-years-curriculum/
#   ✅ Extracted 1049 words
# Scraping https://www.sunmarke.com/learning/eyfs/eyfs-enriched-learning/
#   ✅ Extracted 240 words
# Scraping https://www.sunmarke.com/learning/primary/our-approach-primary/
#   ✅ Extracted 478 words
# Scraping https://www.sunmarke.com/learning/primary/our-curriculum-primary/
#   ✅ Extracted 374 words
# Scraping https://www.sunmarke.com/learning/primary/sports-pe-primary/
#   ✅ Extracted 181 words
# Scraping https://www.sunmarke.com/learning/primary/creative-performing-arts-primary/
#   ✅ Extracted 386 words
# Scraping https://www.sunmarke.com/learning/primary/enriched-learning-primary/
#   ✅ Extracted 2135 words
# Scraping https://www.sunmarke.com/learning/coding/
#   ✅ Extracted 261 words
# Scraping https://www.sunmarke.com/learning/primary/student-council-and-ambassadors/
#   ✅ Extracted 212 words
# Scraping https://www.sunmarke.com/learning/secondary/our-approach-secondary/
#   ✅ Extracted 866 words
# Scraping https://www.sunmarke.com/learning/secondary/our-curriculum-secondary/
#   ✅ Extracted 4462 words
# Scraping https://www.sunmarke.com/learning/secondary/sports-pe-secondary/
#   ✅ Extracted 399 words
# Scraping https://www.sunmarke.com/learning/secondary/secondary-creative-performing-arts/
#   ✅ Extracted 410 words
# Scraping https://www.sunmarke.com/learning/secondary/enriched-learning-secodary/
#   ✅ Extracted 1022 words
# Scraping https://www.sunmarke.com/learning/coding/
#   ✅ Extracted 261 words
# Scraping https://www.sunmarke.com/learning/secondary/sunmarke-mini-mba/
#   ✅ Extracted 133 words
# Scraping https://www.sunmarke.com/learning/secondary/student-council-and-ambassadors-secondary/
#   ⚠️ No meaningful text found
# Scraping https://www.sunmarke.com/learning/sixth-form/our-approach-sixth-form/
#   ✅ Extracted 931 words
# Scraping https://www.sunmarke.com/learning/sixth-form/a-levels/
#   ✅ Extracted 403 words
# Scraping https://www.sunmarke.com/learning/sixth-form/btecs/
#   ✅ Extracted 361 words
# Scraping https://www.sunmarke.com/learning/sixth-form/ib-diploma-programme-ibdp/
#   ✅ Extracted 653 words
# Scraping https://www.sunmarke.com/learning/sixth-form/student-enrichment/
#   ✅ Extracted 146 words
# Scraping https://www.sunmarke.com/learning/coding/
#   ✅ Extracted 261 words
# Scraping https://www.sunmarke.com/learning/sixth-form/civitas/
#   ✅ Extracted 368 words
# Scraping https://www.sunmarke.com/learning/sixth-form/careers-counsellor/
#   ✅ Extracted 1222 words
# Scraping https://www.sunmarke.com/learning/sixth-form/student-leadership/
#   ⚠️ No meaningful text found
# Scraping https://www.sunmarke.com/signature-programmes/steam-design-thinking/
#   ✅ Extracted 563 words
# Scraping https://www.sunmarke.com/signature-programmes/environment-and-sustainability/
#   ✅ Extracted 625 words
# Scraping https://www.sunmarke.com/signature-programmes/university-career-readiness-programme/
#   ✅ Extracted 669 words
# Scraping https://www.sunmarke.com/signature-programmes/fortes-pro-sports-academy/
#   ✅ Extracted 626 words
# Scraping https://www.sunmarke.com/signature-programmes/positive-education/
#   ✅ Extracted 606 words
# Scraping https://www.sunmarke.com/signature-programmes/global-language-academy/
#   ✅ Extracted 575 words
# Scraping https://www.sunmarke.com/signature-programmes/financial-literacy-programme/
#   ✅ Extracted 608 words
# Scraping https://www.sunmarke.com/signature-programmes/enterprise-mini-mba-programme/
#   ✅ Extracted 598 words
# Scraping https://www.sunmarke.com/signature-programmes/communications-media-the-performing-arts-programme/
#   ✅ Extracted 616 words
# Scraping https://applynow.sunmarke.com/
#   ⚠️ No meaningful text found
# Scraping https://enquiry.sunmarke.com/enrolment-campaign?s=WEB
#   ✅ Extracted 801 words
# Scraping https://www.sunmarke.com/admissions/tuition-fees/
#   ✅ Extracted 854 words
# Scraping https://www.sunmarke.com/admissions/scholarships/
#   ✅ Extracted 1222 words
# Scraping https://www.sunmarke.com/admissions/re-enrol-online/
#   ✅ Extracted 174 words
# Scraping https://www.sunmarke.com/admissions/school-forms/
#   ✅ Extracted 51 words
# Scraping https://www.sunmarke.com/admissions/faqs/
#   ✅ Extracted 6034 words
# Scraping https://www.sunmarke.com/for-parents/school-uniform/
#   ✅ Extracted 343 words
# Scraping https://www.sunmarke.com/for-parents/school-timings/
#   ✅ Extracted 128 words
# Scraping https://www.sunmarke.com/for-parents/academic-calendar/
#   ⚠️ No meaningful text found
# Scraping https://www.sunmarke.com/school-calendar-events
#   ⚠️ No meaningful text found
# Scraping https://www.sunmarke.com/for-parents/policies/
#   ✅ Extracted 65 words
# Scraping https://www.sunmarke.com/for-parents/transport-services/
#   ✅ Extracted 358 words
# Scraping https://www.sunmarke.com/for-parents/dining-catering/
#   ✅ Extracted 237 words
# Scraping https://sports.sunmarke.com/
#   ✅ Extracted 180 words
# Scraping https://www.sunmarke.com/for-parents/parent-engagement/
#   ✅ Extracted 295 words
# Scraping https://www.sunmarke.com/for-parents/governance-committee/
#   ✅ Extracted 407 words
# Scraping https://www.sunmarke.com/activities/sunmarke-free-ecas/
#   ✅ Extracted 601 words
# Scraping https://www.sunmarke.com/activities/sunmarke-paid-ecas/
#   ✅ Extracted 175 words
# Scraping https://www.sunmarke.com/activities/third-party-paid-ecas/
#   ✅ Extracted 4431 words
# Scraping https://www.sunmarke.com/news-events/weekly-buzz/
#   ✅ Extracted 108 words
# Scraping https://www.sunmarke.com/news-events/blog/
#   ✅ Extracted 349 words
# Scraping https://www.sunmarke.com/news-events/press/
#   ✅ Extracted 982 words
# Scraping https://www.sunmarke.com/news-events/podcasts/
#   ✅ Extracted 290 words
# Scraping https://www.sunmarke.com/contact-us/
#   ✅ Extracted 87 words
# Scraping https://www.sunmarke.com/contact-us/work-with-us/
#   ✅ Extracted 513 words

# %%
# save extracted documents to data.json
# save data to a json
import json

with open("data.json", "w") as file:
    json.dump(data, file, indent=4)
